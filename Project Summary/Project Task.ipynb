# %% [markdown]
# #**Task-1 Department wise performances**

# %%
import numpy as np
import pandas as pd

# %%
data1=pd.read_csv("/content/INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.csv")
data1.head(2)
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single         Sales
# 1  E1001006   47   Male           Marketing        Single         Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# 1                  4  ...                            4
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          10                      2                   2
# 1                          20                      2                   3
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# ...

# %%
department_groups = data1.groupby('EmpDepartment')

# %%
department_performance = department_groups['PerformanceRating'].mean()

# %%
import matplotlib.pyplot as plt

# Assuming 'department_performance' is a Series containing department-wise performance
department_performance.plot(kind='bar')
plt.title('Department-wise Performance')
plt.xlabel('Department')
plt.ylabel('Average Performance Rating')
plt.show()

# %% [markdown]
# ##**Report:**
#
# ###  Development department will be very high performance rating and Datascience also high. Human resources and research & development both are slightly differ from its range of their performance. Finally sales department and finance department are low performamce rated among others.

# %% [markdown]
# #**Task-2     Top 3 Important Factors Affecting Employee Performance**

# %%
data.to_csv("Preprocessed_data.csv")

# %%
Preprocessed_data=pd.read_csv("Preprocessed_data.csv")
Preprocessed_data
# Out:
#       Unnamed: 0  Age  Gender  Edu_Background  MaritalStatus  Emp_Dept  \
# 0              0   32       1               3              2         5
# 1              1   47       1               3              2         5
# 2              2   40       1               5              1         5
# 3              3   41       1               0              0         2
# 4              4   60       1               3              2         5
# ...          ...  ...     ...             ...            ...       ...
# 1195        1195   27       0               4              0         5
# 1196        1196   37       1               5              2         4
# 1197        1197   50       1               4              1         4
# 1198        1198   34       0               4              2         0
# 1199        1199   24       0               5              2         5
#
#       Emp_JobRole  Busi_Trav_Freq  Dist_From_Home  Emp_Edu_Level  ...  \
# ...

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# Assuming 'data' is your DataFrame
x = Preprocessed_data.drop('Performance_Rating', axis=1)
y = Preprocessed_data['Performance_Rating']

# Train a Random Forest model
model = RandomForestRegressor()
model.fit(x, y)

# Get feature importances
feature_importances = pd.Series(model.feature_importances_, index=x.columns).sort_values(ascending=False)

# Display the top 3 important factors
top_3_factors = feature_importances.head(3)
print(top_3_factors)
# Out:
# Last_Sal_Hike_Perc       0.398036
# Emp_Envi_Satisfaction    0.173599
# EmpWork_LifeBal          0.072633
# dtype: float64

# %% [markdown]
# ##**Report:**
#
#   All the Features are basically  affect the performance rating as well. But mainly top 3 features:
#
#    **Last_sal_hike percentage:** This is the percentage increase in an employee's salary during the most recent salary hike or adjustment.
#
#
#   **Emp_Envi_Satisfaction:**  It measure how satisfied an employee is with the physical and social aspects of their work environment.
#
#    **EmpWork_LifeBal:** It measure of how an employee perceives their ability to balance the demands of their job with other aspects of their life, such as family, personal interests, and leisure.

# %% [markdown]
# #**Task-3 A trained model which can predict the employee performance based on factors as inputs. This will be used to hire employees.**

# %% [markdown]
# Yes, using a trained machine learning model to predict employee performance based on various factors is a common application in human resources and talent acquisition. Organizations can leverage predictive modeling to assess and predict the potential performance of job candidates during the hiring process.
#
# Here are the general steps involved in building and deploying such a model:
#
# 1. **Data Collection:**
#    - Gather historical data on current and past employees, including information on their performance, skills, education, experience, and any other relevant features.
#
# 2. **Data Preprocessing:**
#    - Clean and preprocess the data to handle missing values, encode categorical variables, and scale numerical features. This step is crucial for preparing the data for model training.
#
# 3. **Feature Selection:**
#    - Identify and select the most relevant features (input variables) for predicting employee performance. This can be done through statistical analysis, feature importance from models, or domain knowledge.
#
# 4. **Model Selection:**
#    - Choose an appropriate machine learning model for the task. Common models for predictive analytics in HR include regression models, decision trees, random forests, and gradient boosting algorithms.
#
# 5. **Model Training:**
#    - Train the selected model on the historical data, using a portion of the data for training and another portion for validation. The model learns patterns and relationships between input features and the target variable (employee performance).
#
# 6. **Model Evaluation:**
#    - Evaluate the model's performance using metrics such as accuracy, precision, recall, and F1 score. Adjust the model and hyperparameters as needed to improve performance.
#
# 7. **Deployment:**
#    - Once satisfied with the model's performance, deploy it to a production environment where it can be used to make predictions on new data.
#
# 8. **Integration with Hiring Process:**
#    - Integrate the model into the hiring process. When evaluating new job candidates, input their relevant information into the model, and receive a prediction of their potential performance.
#
# 9. **Continuous Monitoring and Improvement:**
#    - Regularly monitor the model's performance in a real-world setting. Retrain the model periodically with new data to ensure it remains accurate and relevant.
#
#
# ##**Result:**
#
#
#
# It's important to note that while predictive models can provide valuable insights, they should be used as a tool to support decision-making rather than as the sole determinant. Human judgment, ethical considerations, and legal compliance should always play a crucial role in the hiring process.

# %% [markdown]
# #**Task-4 Recommendations to improve the employee performance based on insights from analysis.**

# %% [markdown]
# Improving employee performance based on insights from analysis involves identifying areas for enhancement and implementing targeted strategies. Here are some general recommendations based on common analysis findings:
#
# 1. **Training and Development:**
#    - **Insight:** Identify skills gaps or areas where employees may benefit from additional training.
#    - **Recommendation:** Implement training and development programs to enhance employees' skills and knowledge. This could include workshops, online courses, or mentorship programs.
#
# 2. **Recognition and Rewards:**
#    - **Insight:** Recognize and reward high-performing employees to boost morale and motivation.
#    - **Recommendation:** Establish a recognition program that acknowledges and rewards outstanding performance. This could include bonuses, certificates, or public recognition.
#
# 3. **Feedback and Communication:**
#    - **Insight:** Assess the effectiveness of communication channels and the availability of constructive feedback.
#    - **Recommendation:** Foster a culture of open communication and regular feedback. Conduct performance reviews and provide constructive feedback to help employees understand their strengths and areas for improvement.
#
# 4. **Work-Life Balance:**
#    - **Insight:** Evaluate employees' perceptions of work-life balance.
#    - **Recommendation:** Implement policies and initiatives that support work-life balance, such as flexible working hours, remote work options, or wellness programs.
#
# 5. **Career Growth Opportunities:**
#    - **Insight:** Understand employees' aspirations and career development needs.
#    - **Recommendation:** Provide opportunities for career growth within the organization. This could include career advancement programs, mentorship, and succession planning.
#
# 6. **Team Collaboration:**
#    - **Insight:** Analyze team dynamics and collaboration.
#    - **Recommendation:** Encourage teamwork and collaboration through team-building activities, cross-functional projects, and communication tools that facilitate collaboration.
#
# 7. **Managerial Support:**
#    - **Insight:** Assess the effectiveness of managerial support and leadership.
#    - **Recommendation:** Provide leadership training for managers to enhance their ability to support and motivate their teams. Encourage a leadership style that fosters a positive work environment.
#
# 8. **Wellness Programs:**
#    - **Insight:** Consider the impact of employee well-being on performance.
#    - **Recommendation:** Implement wellness programs that address physical and mental well-being. This could include health screenings, stress management workshops, or Employee Assistance Programs (EAPs).
#
# 9. **Performance Incentives:**
#    - **Insight:** Analyze the relationship between performance incentives and motivation.
#    - **Recommendation:** Design performance incentives that align with organizational goals and motivate employees to excel. This could include performance-based bonuses or other recognition programs.
#
# 10. **Continuous Improvement:**
#     - **Insight:** Regularly monitor and analyze employee performance metrics.
#     - **Recommendation:** Establish a continuous improvement process. Regularly review performance metrics, gather feedback, and adjust strategies to ensure ongoing effectiveness.
#
#
# ##**Result:**
#
# It's important to tailor these recommendations to the specific insights gained from your analysis and the unique context of your organization. Additionally, involving employees in the decision-making process and considering their feedback is key to the success of improvement initiatives.
